# %%
import tensorflow as tf
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=[]
df=pd.read_csv("FIFA - World Cup Summary.csv")

df
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...

# %%
yeniveri={"YEAR":2022,"HOST":np.nan,"CHAMPION":"Turkey","RUNNER UP":np.nan,"THIRD PLACE":np.nan,"TEAMS":32,"MATCHES PLAYED":64,"GOALS SCORED":np.nan,"AVG GOALS PER GAME":np.nan}
yeniveri=pd.DataFrame(yeniveri,index=[len(df)])
df=pd.concat([df,yeniveri])
df
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...

# %%
""""yeniveri={"YEAR":2022,"HOST":np.nan,"CHAMPION":"Turkey","RUNNER UP":np.nan,"THIRD PLACE":np.nan,"TEAMS":32,"MATCHES PLAYED":64,"GOALS SCORED":np.nan,"AVG GOALS PER GAME":np.nan}
yeniveri=pd.DataFrame(yeniveri,index=[len(df)])
df=pd.concat([df,yeniveri])
df_years=df["YEAR"]
df=df.drop("YEAR",axis=1)
df["years"]=df_years
df
df["year"]=df_years
df"""

# %%
df
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...

# %%
"""
df_years=df["YEAR"]
df=df.drop("YEAR",axis=1)
df["years"]=df_years
df
df["year"]=df_years
df"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\tenserflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\tenserflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\tenserflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
yeniveri={"YEAR":(len(df))*4+1930,"HOST":np.nan,"CHAMPION":"Turkey","RUNNER UP":np.nan,"THIRD PLACE":np.nan,"TEAMS":32,"MATCHES PLAYED":64,"GOALS SCORED":np.nan,"AVG GOALS PER GAME":np.nan}

# %%
yeniveri=pd.DataFrame(yeniveri,index=[len(df)])
df=pd.concat([df,yeniveri])
df
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...

# %%
df=df[0:len(df)-4]
df
# Out:
#     YEAR                HOST      CHAMPION       RUNNER UP    THIRD PLACE  \
# 0   1930             Uruguay       Uruguay       Argentina  United States
# 1   1934               Italy         Italy  Czechoslovakia        Germany
# 2   1938              France         Italy         Hungary         Brazil
# 3   1950              Brazil       Uruguay          Brazil         Sweden
# 4   1954         Switzerland  West Germany         Hungary        Austria
# 5   1958              Sweden        Brazil          Sweden         France
# 6   1962               Chile        Brazil  Czechoslovakia          Chile
# 7   1966             England       England    West Germany       Portugal
# 8   1970              Mexico        Brazil           Italy   West Germany
# 9   1974        West Germany  West Germany     Netherlands         Poland
# 10  1978           Argentina     Argentina     Netherlands         Brazil
# 11  1982               Spain         Italy    West Germany         Poland
# ...
